# %%
# !pip install numpy==1.15
# Out:
# Collecting numpy==1.15
#   Downloading https://files.pythonhosted.org/packages/88/29/f4c845648ed23264e986cdc5fbab5f8eace1be5e62144ef69ccc7189461d/numpy-1.15.0-cp36-cp36m-manylinux1_x86_64.whl (13.9MB)
#     100% |████████████████████████████████| 13.9MB 3.3MB/s
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.8 which is incompatible.
# Installing collected packages: numpy
#   Found existing installation: numpy 1.16.2
#     Uninstalling numpy-1.16.2:
#       Successfully uninstalled numpy-1.16.2
# Successfully installed numpy-1.15.0

# %%
# !pip install --upgrade pandas folium imgaug
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/19/74/e50234bc82c553fecdbd566d8650801e3fe2d6d8c8d940638e3d8a7c5522/pandas-0.24.2-cp36-cp36m-manylinux1_x86_64.whl (10.1MB)
#     100% |████████████████████████████████| 10.1MB 4.3MB/s
# Requirement already up-to-date: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already up-to-date: imgaug in /usr/local/lib/python3.6/dist-packages (0.2.8)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.15.0)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.10.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.11.0)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.3.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.18.4)
# Requirement already satisfied, skipping upgrade: imageio in /usr/local/lib/python3.6/dist-packages (from imgaug) (2.4.1)
# Requirement already satisfied, skipping upgrade: Pillow in /usr/local/lib/python3.6/dist-packages (from imgaug) (4.3.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.6/dist-packages (from imgaug) (3.0.3)
# Requirement already satisfied, skipping upgrade: opencv-python in /usr/local/lib/python3.6/dist-packages (from imgaug) (3.4.5.20)
# Requirement already satisfied, skipping upgrade: Shapely in /usr/local/lib/python3.6/dist-packages (from imgaug) (1.6.4.post2)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from imgaug) (1.2.1)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug) (0.14.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.6)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.22)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->imgaug) (0.46)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->imgaug) (2.4.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->imgaug) (1.0.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->imgaug) (0.10.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug) (1.0.3)
# Requirement already satisfied, skipping upgrade: cloudpickle>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug) (0.6.1)
# Requirement already satisfied, skipping upgrade: networkx>=1.8 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug) (2.2)
# Requirement already satisfied, skipping upgrade: dask[array]>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug) (1.1.5)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib->imgaug) (40.9.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=1.8->scikit-image>=0.11.0->imgaug) (4.4.0)
# Requirement already satisfied, skipping upgrade: toolz>=0.7.3; extra == "array" in /usr/local/lib/python3.6/dist-packages (from dask[array]>=1.0.0->scikit-image>=0.11.0->imgaug) (0.9.0)
# Installing collected packages: pandas
#   Found existing installation: pandas 0.23.4
#     Uninstalling pandas-0.23.4:
#       Successfully uninstalled pandas-0.23.4
# Successfully installed pandas-0.24.2

# %%
# !pip3 install https://download.pytorch.org/whl/cu90/torch-1.0.0-cp36-cp36m-linux_x86_64.whl
# Out:
# Collecting torch==1.0.0 from https://download.pytorch.org/whl/cu90/torch-1.0.0-cp36-cp36m-linux_x86_64.whl
#   Downloading https://download.pytorch.org/whl/cu90/torch-1.0.0-cp36-cp36m-linux_x86_64.whl (591.8MB)
#     100% |████████████████████████████████| 591.8MB 22kB/s
# Installing collected packages: torch
#   Found existing installation: torch 1.0.1.post2
#     Uninstalling torch-1.0.1.post2:
#       Successfully uninstalled torch-1.0.1.post2
# Successfully installed torch-1.0.0

# %%
# !pip3 install torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.2.post3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (4.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.0.1.post2)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision) (0.46)

# %%
# !pip install pytorch-pretrained-bert==v0.6.1
# Out:
# Collecting pytorch-pretrained-bert==v0.6.1
#   Downloading https://files.pythonhosted.org/packages/5d/3c/d5fa084dd3a82ffc645aba78c417e6072ff48552e3301b1fa3bd711e03d4/pytorch_pretrained_bert-0.6.1-py3-none-any.whl (114kB)
#     100% |████████████████████████████████| 122kB 4.6MB/s
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (1.0.1.post2)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (2018.1.10)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (1.9.130)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1) (2.18.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert==v0.6.1) (1.12.130)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert==v0.6.1) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert==v0.6.1) (0.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert==v0.6.1) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert==v0.6.1) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert==v0.6.1) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert==v0.6.1) (2019.3.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->pytorch-pretrained-bert==v0.6.1) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->pytorch-pretrained-bert==v0.6.1) (0.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.130->boto3->pytorch-pretrained-bert==v0.6.1) (1.11.0)
# Installing collected packages: pytorch-pretrained-bert
# Successfully installed pytorch-pretrained-bert-0.6.1

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 107, done.
# remote: Total 107 (delta 0), reused 0 (delta 0), pack-reused 107
# Receiving objects: 100% (107/107), 378.81 KiB | 3.91 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
cd bert-sklearn
# Out:
# /content/bert-sklearn

# %%
# !pip install .
# Out:
# Processing /content/bert-sklearn
# Requirement already satisfied: pytorch-pretrained-bert==v0.6.1 in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (0.6.1)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (1.0.1.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (0.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (1.15.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (1.9.130)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from bert-sklearn==0.2.0) (4.28.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert==v0.6.1->bert-sklearn==0.2.0) (2018.1.10)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->bert-sklearn==0.2.0) (1.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.130 in /usr/local/lib/python3.6/dist-packages (from boto3->bert-sklearn==0.2.0) (1.12.130)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->bert-sklearn==0.2.0) (0.2.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->bert-sklearn==0.2.0) (0.9.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->bert-sklearn==0.2.0) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->bert-sklearn==0.2.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->bert-sklearn==0.2.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->bert-sklearn==0.2.0) (1.22)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->bert-sklearn==0.2.0) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.130->boto3->bert-sklearn==0.2.0) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.130->boto3->bert-sklearn==0.2.0) (1.11.0)
# Building wheels for collected packages: bert-sklearn
#   Building wheel for bert-sklearn (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/61/95/c6/5790aae8fb377f5ff356dbe58205aab28858595d6bff8197d0
# Successfully built bert-sklearn
# Installing collected packages: bert-sklearn
# Successfully installed bert-sklearn-0.2.0

# %%
cd ..
# Out:
# /content

# %%
# !dir
# Out:
# bert-sklearn  sample_data

# %%
import numpy as np
import pandas as pd
import os
import sys
import csv
from sklearn import metrics
from sklearn.metrics import classification_report

sys.path.append("../") 
from bert_sklearn import BertClassifier
from bert_sklearn import load_model
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131304 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.3-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !mkdir -p glue_data

# %%
cd glue_data
# Out:
# /content/glue_data/original/glue_data

# %%
# !mkdir -p CoLA

# %%
cd CoLA
# Out:
# /content/glue_data/CoLA

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b86ca65a-1bff-4e44-b82c-df9327bafcfe" name="files[]" multiple disabled />
#      <output id="result-b86ca65a-1bff-4e44-b82c-df9327bafcfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dev.tsv to dev.tsv
# Saving test.tsv to test.tsv
# Saving train.tsv to train.tsv

# %%
# !mkdir -p original

# %%
cd original
# Out:
# /content/glue_data/CoLA/original

# %%
# !mkdir -p raw

# %%
cd raw
# Out:
# /content/glue_data/CoLA/original/raw

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-49e33ef6-ebe7-4261-a6e8-e3ceaaf82c15" name="files[]" multiple disabled />
#      <output id="result-49e33ef6-ebe7-4261-a6e8-e3ceaaf82c15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving in_domain_dev.tsv to in_domain_dev.tsv
# Saving in_domain_train.tsv to in_domain_train.tsv
# Saving out_of_domain_dev.tsv to out_of_domain_dev.tsv

# %%
cd ..
# Out:
# /content/glue_data/CoLA/original

# %%
# !mkdir -p tokenized

# %%
cd tokenized
# Out:
# /content/glue_data/CoLA/original/tokenized

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9402490-d606-4f37-824f-5a180e62aa18" name="files[]" multiple disabled />
#      <output id="result-d9402490-d606-4f37-824f-5a180e62aa18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving in_domain_dev.tsv to in_domain_dev.tsv
# Saving in_domain_train.tsv to in_domain_train.tsv
# Saving out_of_domain_dev.tsv to out_of_domain_dev.tsv

# %%
cd ..
# Out:
# /content

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a1e718a-7131-4d9b-921c-4fba47aaa557" name="files[]" multiple disabled />
#      <output id="result-8a1e718a-7131-4d9b-921c-4fba47aaa557">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download_glue_data.py to download_glue_data.py

# %%
DATADIR = os.getcwd() + '/glue_data'

# %%
# !python3 download_glue_data.py --data_dir glue_data --tasks CoLA
# Out:
# Downloading and extracting CoLA...
# 	Completed!

# %%
"""
CoLA train data size: 8551 
CoLA dev data size: 1043 
"""

def get_cola_df(filename,cols = [3,1]):
    df = pd.read_csv(filename, sep='\t',  encoding = 'utf8',keep_default_na=False,header=None)
    df = df[cols]
    df.columns=['text','label']
    return df

def get_cola_data(train_file = DATADIR+'/CoLA/train.tsv', 
                   dev_file =  DATADIR+'/CoLA/dev.tsv'):
    
    train = get_cola_df(train_file)
    print("CoLA train data size: %d "%(len(train)))
    dev = get_cola_df(dev_file)
    print("CoLA dev data size: %d "%(len(dev)))

    label_list = np.unique(train['label'].values)
    return train,dev,label_list  
                  
train,dev,label_list =  get_cola_data()
# Out:
# CoLA train data size: 8551
# CoLA dev data size: 1043

# %%
print(label_list)
# Out:
# [0 1]

# %%
train = train.sample(len(train))

# %%
train.head()
# Out:
#                                                    text  label
# 744                Frank promised the men all to leave.      0
# 860   Sally might have eaten cabbage, but Holly shou...      1
# 5366        Sally eats caviar more than I had expected.      1
# 2639           Brian wiped the counter of fingerprints.      0
# 4521                                 They'd leave soon.      1

# %%
from sklearn.model_selection import GridSearchCV

X_train = train['text']
y_train = train['label']



params = {'learning_rate':[2e-5, 3e-5]} #'train_batch_size':[32, 64]

# wrap classifier/regressor in GridSearchCV
clf = GridSearchCV(BertClassifier(epochs = 3), 
                    params,
                    scoring='accuracy',
                    verbose=True)

# fit gridsearch 
clf.fit(X_train ,y_train)
# Out:
# Building sklearn classifier...
# Building sklearn classifier...
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# Building sklearn classifier...
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 100%|██████████| 231508/231508 [00:00<00:00, 2620066.35B/s]
# Loading bert-base-uncased model...
# 100%|██████████| 407873900/407873900 [00:08<00:00, 49002638.32B/s]
# Defaulting to linear classifier/regressor
# train data size: 5130, validation data size: 570
# Training: 100%|██████████| 161/161 [03:58<00:00,  1.23s/it, loss=0.536]
# Epoch 1, Train loss : 0.5363, Val loss: 0.4660, Val accy = 78.07%
# Training: 100%|██████████| 161/161 [03:59<00:00,  1.23s/it, loss=0.253]
# Epoch 2, Train loss : 0.2531, Val loss: 0.5149, Val accy = 77.72%
# Training: 100%|██████████| 161/161 [04:00<00:00,  1.24s/it, loss=0.113]
# Epoch 3, Train loss : 0.1135, Val loss: 0.6489, Val accy = 79.12%
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 5130, validation data size: 570
# Training: 100%|██████████| 161/161 [04:00<00:00,  1.24s/it, loss=0.55]
# Epoch 1, Train loss : 0.5500, Val loss: 0.4314, Val accy = 80.88%
# Training: 100%|██████████| 161/161 [04:01<00:00,  1.25s/it, loss=0.293]
# Epoch 2, Train loss : 0.2925, Val loss: 0.4956, Val accy = 81.75%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.25s/it, loss=0.137]
# Epoch 3, Train loss : 0.1368, Val loss: 0.5014, Val accy = 83.16%
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 5132, validation data size: 570
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.27s/it, loss=0.546]
# Epoch 1, Train loss : 0.5460, Val loss: 0.4186, Val accy = 81.93%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.26s/it, loss=0.271]
# Epoch 2, Train loss : 0.2708, Val loss: 0.4248, Val accy = 83.16%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.27s/it, loss=0.117]
# Epoch 3, Train loss : 0.1167, Val loss: 0.5366, Val accy = 84.04%
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 5130, validation data size: 570
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.25s/it, loss=0.548]
# Epoch 1, Train loss : 0.5483, Val loss: 0.4905, Val accy = 77.37%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.24s/it, loss=0.261]
# Epoch 2, Train loss : 0.2611, Val loss: 0.5544, Val accy = 77.37%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.24s/it, loss=0.095]
# Epoch 3, Train loss : 0.0950, Val loss: 0.7149, Val accy = 77.89%
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 5130, validation data size: 570
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.25s/it, loss=0.555]
# Epoch 1, Train loss : 0.5548, Val loss: 0.4672, Val accy = 78.42%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.25s/it, loss=0.301]
# Epoch 2, Train loss : 0.3014, Val loss: 0.5068, Val accy = 80.18%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.24s/it, loss=0.12]
# Epoch 3, Train loss : 0.1203, Val loss: 0.6602, Val accy = 80.70%
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 5132, validation data size: 570
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.27s/it, loss=0.576]
# Epoch 1, Train loss : 0.5757, Val loss: 0.4872, Val accy = 75.61%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.27s/it, loss=0.335]
# Epoch 2, Train loss : 0.3353, Val loss: 0.4773, Val accy = 81.23%
# Training: 100%|██████████| 161/161 [04:02<00:00,  1.27s/it, loss=0.154]
# Epoch 3, Train loss : 0.1541, Val loss: 0.5443, Val accy = 81.40%
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 91.3min finished
# Building sklearn classifier...
# Loading bert-base-uncased model...
# Defaulting to linear classifier/regressor
# train data size: 7696, validation data size: 855
# Training: 100%|██████████| 241/241 [06:03<00:00,  1.32s/it, loss=0.515]
# Epoch 1, Train loss : 0.5148, Val loss: 0.4081, Val accy = 82.92%
# Training: 100%|██████████| 241/241 [06:04<00:00,  1.32s/it, loss=0.261]
# Epoch 2, Train loss : 0.2607, Val loss: 0.4386, Val accy = 83.86%
# Training: 100%|██████████| 241/241 [06:03<00:00,  1.32s/it, loss=0.128]
# Epoch 3, Train loss : 0.1276, Val loss: 0.5076, Val accy = 85.50%
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=BertClassifier(bert_model='bert-base-uncased', epochs=3, eval_batch_size=8,
#         fp16=False, gradient_accumulation_steps=1, label_list=None,
#         learning_rate=2e-05, local_rank=-1, logfile='bert_sklearn.log',
#         loss_scale=0, max_seq_length=128, num_mlp_hiddens=500,
#         num_mlp_layers=0, random_state=42, restore_file=None,
#         train_batch_size=32, use_cuda=True, validation_fraction=0.1,
#         warmup_proportion=0.1),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'learning_rate': [2e-05, 3e-05]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=True)

# %%
# best scores
print(clf.best_score_, clf.best_params_)

means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7c53f3218a6> in <module>()
# ----> 1 print(clf.best_score_, clf.best_params_)
#       2
#       3 means = clf.cv_results_['mean_test_score']
#       4 stds = clf.cv_results_['std_test_score']
#       5
#
# NameError: name 'clf' is not defined

# %%
# %%time
from sklearn.model_selection import GridSearchCV

params = {'epochs':[3, 5], 'learning_rate':[2e-5, 3e-5], 'eval_batch_size':[8, 16], 'train_batch_size':[32, 64], 'validation_fraction':[0.2, 0.3]}

# wrap classifier/regressor in GridSearchCV
clf = GridSearchCV(BertClassifier(), 
                    params,
                    scoring='accuracy',
                    verbose=True)

# fit gridsearch 
clf.fit(X_train ,y_train)
# Out:
# Building sklearn classifier...
# Building sklearn classifier...
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Building sklearn classifier...
# Loading bert-base-uncased model...
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Defaulting to linear classifier/regressor
# train data size: 4560, validation data size: 1140
# Training:   0%|          | 0/143 [00:00<?, ?it/s]
# Training:   0%|          | 0/143 [00:01<?, ?it/s, loss=0.842]
# Training:   1%|          | 1/143 [00:02<04:43,  2.00s/it, loss=0.842]
# Training:   1%|          | 1/143 [00:03<04:43,  2.00s/it, loss=0.847]
# Training:   1%|▏         | 2/143 [00:03<04:24,  1.88s/it, loss=0.847]
# Training:   1%|▏         | 2/143 [00:05<04:24,  1.88s/it, loss=0.821]
# Training:   2%|▏         | 3/143 [00:05<04:11,  1.80s/it, loss=0.821]
# Training:   2%|▏         | 3/143 [00:06<04:11,  1.80s/it, loss=0.821]
# Training:   3%|▎         | 4/143 [00:06<04:02,  1.74s/it, loss=0.821]
# Training:   3%|▎         | 4/143 [00:08<04:02,  1.74s/it, loss=0.822]
# Training:   3%|▎         | 5/143 [00:08<03:54,  1.70s/it, loss=0.822]
# Training:   3%|▎         | 5/143 [00:10<03:54,  1.70s/it, loss=0.811]
# Training:   4%|▍         | 6/143 [00:10<03:48,  1.67s/it, loss=0.811]
# Training:   4%|▍         | 6/143 [00:11<03:48,  1.67s/it, loss=0.801]
# Training:   5%|▍         | 7/143 [00:11<03:43,  1.65s/it, loss=0.801]
# Training:   5%|▍         | 7/143 [00:13<03:43,  1.65s/it, loss=0.787]
# Training:   6%|▌         | 8/143 [00:13<03:40,  1.63s/it, loss=0.787]
# Training:   6%|▌         | 8/143 [00:14<03:40,  1.63s/it, loss=0.78]
# Training:   6%|▋         | 9/143 [00:14<03:36,  1.62s/it, loss=0.78]
# Training:   6%|▋         | 9/143 [00:16<03:36,  1.62s/it, loss=0.773]
# Training:   7%|▋         | 10/143 [00:16<03:33,  1.61s/it, loss=0.773]
# Training:   7%|▋         | 10/143 [00:17<03:33,  1.61s/it, loss=0.76]
# Training:   8%|▊         | 11/143 [00:17<03:31,  1.60s/it, loss=0.76]
# Training:   8%|▊         | 11/143 [00:19<03:31,  1.60s/it, loss=0.751]
# Training:   8%|▊         | 12/143 [00:19<03:29,  1.60s/it, loss=0.751]
# Training:   8%|▊         | 12/143 [00:21<03:29,  1.60s/it, loss=0.741]
# Training:   9%|▉         | 13/143 [00:21<03:28,  1.60s/it, loss=0.741]
# Training:   9%|▉         | 13/143 [00:22<03:28,  1.60s/it, loss=0.732]
# Training:  10%|▉         | 14/143 [00:22<03:26,  1.60s/it, loss=0.732]
# Training:  10%|▉         | 14/143 [00:24<03:26,  1.60s/it, loss=0.726]
# Training:  10%|█         | 15/143 [00:24<03:24,  1.60s/it, loss=0.726]
# Training:  10%|█         | 15/143 [00:25<03:24,  1.60s/it, loss=0.713]
# Training:  11%|█         | 16/143 [00:25<03:22,  1.60s/it, loss=0.713]
# Training:  11%|█         | 16/143 [00:27<03:22,  1.60s/it, loss=0.708]
# Training:  12%|█▏        | 17/143 [00:27<03:21,  1.60s/it, loss=0.708]
# Training:  12%|█▏        | 17/143 [00:29<03:21,  1.60s/it, loss=0.694]
# Training:  13%|█▎        | 18/143 [00:29<03:19,  1.60s/it, loss=0.694]
# Training:  13%|█▎        | 18/143 [00:30<03:19,  1.60s/it, loss=0.692]
# Training:  13%|█▎        | 19/143 [00:30<03:18,  1.60s/it, loss=0.692]
# Training:  13%|█▎        | 19/143 [00:32<03:18,  1.60s/it, loss=0.681]
# Training:  14%|█▍        | 20/143 [00:32<03:16,  1.60s/it, loss=0.681]
# Training:  14%|█▍        | 20/143 [00:33<03:16,  1.60s/it, loss=0.688]
# Training:  15%|█▍        | 21/143 [00:33<03:14,  1.60s/it, loss=0.688]
# Training:  15%|█▍        | 21/143 [00:35<03:14,  1.60s/it, loss=0.693]
# Training:  15%|█▌        | 22/143 [00:35<03:13,  1.60s/it, loss=0.693]
# Training:  15%|█▌        | 22/143 [00:37<03:13,  1.60s/it, loss=0.682]
# Training:  16%|█▌        | 23/143 [00:37<03:12,  1.60s/it, loss=0.682]
# Training:  16%|█▌        | 23/143 [00:38<03:12,  1.60s/it, loss=0.676]
# Training:  17%|█▋        | 24/143 [00:38<03:10,  1.60s/it, loss=0.676]
# Training:  17%|█▋        | 24/143 [00:40<03:10,  1.60s/it, loss=0.675]
# Training:  17%|█▋        | 25/143 [00:40<03:08,  1.60s/it, loss=0.675]
# Training:  17%|█▋        | 25/143 [00:41<03:08,  1.60s/it, loss=0.672]
# Training:  18%|█▊        | 26/143 [00:41<03:07,  1.60s/it, loss=0.672]
# Training:  18%|█▊        | 26/143 [00:43<03:07,  1.60s/it, loss=0.671]
# Training:  19%|█▉        | 27/143 [00:43<03:04,  1.59s/it, loss=0.671]
# Training:  19%|█▉        | 27/143 [00:45<03:04,  1.59s/it, loss=0.669]
# Training:  20%|█▉        | 28/143 [00:45<03:02,  1.59s/it, loss=0.669]
# Training:  20%|█▉        | 28/143 [00:46<03:02,  1.59s/it, loss=0.666]
# Training:  20%|██        | 29/143 [00:46<03:01,  1.59s/it, loss=0.666]
# Training:  20%|██        | 29/143 [00:48<03:01,  1.59s/it, loss=0.663]
# Training:  21%|██        | 30/143 [00:48<02:59,  1.59s/it, loss=0.663]
# Training:  21%|██        | 30/143 [00:49<02:59,  1.59s/it, loss=0.658]
# Training:  22%|██▏       | 31/143 [00:49<02:58,  1.59s/it, loss=0.658]
# Training:  22%|██▏       | 31/143 [00:51<02:58,  1.59s/it, loss=0.655]
# Training:  22%|██▏       | 32/143 [00:51<02:56,  1.59s/it, loss=0.655]
# Training:  22%|██▏       | 32/143 [00:53<02:56,  1.59s/it, loss=0.656]
# Training:  85%|████████▍ | 121/143 [03:12<00:35,  1.59s/it, loss=0.602]
# Training:  85%|████████▍ | 121/143 [03:14<00:35,  1.59s/it, loss=0.601]
# Training:  85%|████████▌ | 122/143 [03:14<00:33,  1.59s/it, loss=0.601]
# Training:  85%|████████▌ | 122/143 [03:16<00:33,  1.59s/it, loss=0.602]
# Training:  86%|████████▌ | 123/143 [03:16<00:31,  1.58s/it, loss=0.602]
# Training:  86%|████████▌ | 123/143 [03:17<00:31,  1.58s/it, loss=0.602]
# Training:  87%|████████▋ | 124/143 [03:17<00:30,  1.58s/it, loss=0.602]
# Training:  87%|████████▋ | 124/143 [03:19<00:30,  1.58s/it, loss=0.601]
# Training:  87%|████████▋ | 125/143 [03:19<00:28,  1.59s/it, loss=0.601]
# Training:  87%|████████▋ | 125/143 [03:20<00:28,  1.59s/it, loss=0.601]
# Training:  88%|████████▊ | 126/143 [03:20<00:26,  1.59s/it, loss=0.601]
# Training:  88%|████████▊ | 126/143 [03:22<00:26,  1.59s/it, loss=0.599]
# Training:  89%|████████▉ | 127/143 [03:22<00:25,  1.59s/it, loss=0.599]
# Training:  89%|████████▉ | 127/143 [03:24<00:25,  1.59s/it, loss=0.598]
# Training:  90%|████████▉ | 128/143 [03:24<00:23,  1.59s/it, loss=0.598]
# Training:  90%|████████▉ | 128/143 [03:25<00:23,  1.59s/it, loss=0.597]
# Training:  90%|█████████ | 129/143 [03:25<00:22,  1.59s/it, loss=0.597]
# Training:  90%|█████████ | 129/143 [03:27<00:22,  1.59s/it, loss=0.597]
# Training:  91%|█████████ | 130/143 [03:27<00:20,  1.59s/it, loss=0.597]
# Training:  91%|█████████ | 130/143 [03:28<00:20,  1.59s/it, loss=0.596]
# Training:  92%|█████████▏| 131/143 [03:28<00:19,  1.59s/it, loss=0.596]
# Training:  92%|█████████▏| 131/143 [03:30<00:19,  1.59s/it, loss=0.596]
# Training:  92%|█████████▏| 132/143 [03:30<00:17,  1.59s/it, loss=0.596]
# Training:  92%|█████████▏| 132/143 [03:31<00:17,  1.59s/it, loss=0.595]
# Training:  93%|█████████▎| 133/143 [03:32<00:15,  1.59s/it, loss=0.595]
# Training:  93%|█████████▎| 133/143 [03:33<00:15,  1.59s/it, loss=0.595]
# Training:  94%|█████████▎| 134/143 [03:33<00:14,  1.59s/it, loss=0.595]
# Training:  94%|█████████▎| 134/143 [03:35<00:14,  1.59s/it, loss=0.594]
# Training:  94%|█████████▍| 135/143 [03:35<00:12,  1.59s/it, loss=0.594]
# Training:  94%|█████████▍| 135/143 [03:36<00:12,  1.59s/it, loss=0.594]
# Training:  95%|█████████▌| 136/143 [03:36<00:11,  1.59s/it, loss=0.594]
# Training:  95%|█████████▌| 136/143 [03:38<00:11,  1.59s/it, loss=0.594]
# Training:  96%|█████████▌| 137/143 [03:38<00:09,  1.58s/it, loss=0.594]
# Training:  96%|█████████▌| 137/143 [03:39<00:09,  1.58s/it, loss=0.592]
# Training:  97%|█████████▋| 138/143 [03:39<00:07,  1.58s/it, loss=0.592]
# Training:  97%|█████████▋| 138/143 [03:41<00:07,  1.58s/it, loss=0.591]
# Training:  97%|█████████▋| 139/143 [03:41<00:06,  1.58s/it, loss=0.591]
# Training:  97%|█████████▋| 139/143 [03:43<00:06,  1.58s/it, loss=0.59]
# Training:  98%|█████████▊| 140/143 [03:43<00:04,  1.58s/it, loss=0.59]
# Training:  98%|█████████▊| 140/143 [03:44<00:04,  1.58s/it, loss=0.589]
# Training:  99%|█████████▊| 141/143 [03:44<00:03,  1.58s/it, loss=0.589]
# Training:  99%|█████████▊| 141/143 [03:46<00:03,  1.58s/it, loss=0.588]
# Training:  99%|█████████▉| 142/143 [03:46<00:01,  1.58s/it, loss=0.588]
# Training:  99%|█████████▉| 142/143 [03:47<00:01,  1.58s/it, loss=0.588]
# Training: 100%|██████████| 143/143 [03:47<00:00,  1.38s/it, loss=0.588]
#
# Validation:   0%|          | 0/143 [00:00<?, ?it/s]
# Validation:   1%|          | 1/143 [00:00<01:00,  2.34it/s]
# Validation:   1%|▏         | 2/143 [00:00<00:47,  2.95it/s]
# Validation:   2%|▏         | 3/143 [00:00<00:39,  3.58it/s]
# Validation:   3%|▎         | 4/143 [00:00<00:33,  4.19it/s]
# Validation:   3%|▎         | 5/143 [00:00<00:29,  4.71it/s]
# Validation:   4%|▍         | 6/143 [00:01<00:26,  5.25it/s]
# Validation:   5%|▍         | 7/143 [00:01<00:23,  5.73it/s]
# Validation:   6%|▌         | 8/143 [00:01<00:22,  6.12it/s]
# Validation:   6%|▋         | 9/143 [00:01<00:20,  6.43it/s]
# Validation:   7%|▋         | 10/143 [00:01<00:20,  6.49it/s]
# Validation:   8%|▊         | 11/143 [00:01<00:20,  6.59it/s]
# Validation:   8%|▊         | 12/143 [00:01<00:19,  6.61it/s]
# Validation:   9%|▉         | 13/143 [00:02<00:19,  6.75it/s]
# Validation:  10%|▉         | 14/143 [00:02<00:19,  6.79it/s]
# Validation:  10%|█         | 15/143 [00:02<00:18,  6.82it/s]
# Validation:  11%|█         | 16/143 [00:02<00:18,  6.91it/s]
# Validation:  12%|█▏        | 17/143 [00:02<00:18,  6.96it/s]
# Validation:  13%|█▎        | 18/143 [00:02<00:17,  7.01it/s]
# Validation:  13%|█▎        | 19/143 [00:02<00:17,  6.91it/s]
# Validation:  14%|█▍        | 20/143 [00:03<00:17,  6.91it/s]
# Validation:  15%|█▍        | 21/143 [00:03<00:17,  6.92it/s]
# Validation:  15%|█▌        | 22/143 [00:03<00:17,  6.92it/s]
# Validation:  16%|█▌        | 23/143 [00:03<00:17,  6.95it/s]
# Validation:  17%|█▋        | 24/143 [00:03<00:17,  6.97it/s]
# Validation:  17%|█▋        | 25/143 [00:03<00:16,  6.96it/s]
# Validation:  18%|█▊        | 26/143 [00:04<00:16,  6.94it/s]
# Validation:  19%|█▉        | 27/143 [00:04<00:16,  6.96it/s]
# Validation:  20%|█▉        | 28/143 [00:04<00:16,  6.98it/s]
# Training:   2%|▏         | 3/143 [00:06<04:05,  1.75s/it, loss=0.431]
# Training:   3%|▎         | 4/143 [00:06<03:56,  1.70s/it, loss=0.431]
# Training:   3%|▎         | 4/143 [00:08<03:56,  1.70s/it, loss=0.426]
# Training:   3%|▎         | 5/143 [00:08<03:49,  1.67s/it, loss=0.426]
# Training:   3%|▎         | 5/143 [00:09<03:49,  1.67s/it, loss=0.408]
# Training:   4%|▍         | 6/143 [00:09<03:45,  1.64s/it, loss=0.408]
# Training:   4%|▍         | 6/143 [00:11<03:45,  1.64s/it, loss=0.402]
# Training:   5%|▍         | 7/143 [00:11<03:41,  1.63s/it, loss=0.402]
# Training:   5%|▍         | 7/143 [00:13<03:41,  1.63s/it, loss=0.414]
# Training:   6%|▌         | 8/143 [00:13<03:37,  1.61s/it, loss=0.414]
# Training:   6%|▌         | 8/143 [00:14<03:37,  1.61s/it, loss=0.412]
# Training:   6%|▋         | 9/143 [00:14<03:34,  1.60s/it, loss=0.412]
# Training:   6%|▋         | 9/143 [00:16<03:34,  1.60s/it, loss=0.412]
# Training:   7%|▋         | 10/143 [00:16<03:32,  1.60s/it, loss=0.412]
# Training:   7%|▋         | 10/143 [00:17<03:32,  1.60s/it, loss=0.412]
# Training:   8%|▊         | 11/143 [00:17<03:30,  1.59s/it, loss=0.412]
# Training:   8%|▊         | 11/143 [00:19<03:30,  1.59s/it, loss=0.41]
# Training:   8%|▊         | 12/143 [00:19<03:28,  1.59s/it, loss=0.41]
# Training:   8%|▊         | 12/143 [00:20<03:28,  1.59s/it, loss=0.407]
# Training:   9%|▉         | 13/143 [00:20<03:26,  1.59s/it, loss=0.407]
# Training:   9%|▉         | 13/143 [00:22<03:26,  1.59s/it, loss=0.401]
# Training:  10%|▉         | 14/143 [00:22<03:25,  1.59s/it, loss=0.401]
# Training:  10%|▉         | 14/143 [00:24<03:25,  1.59s/it, loss=0.39]
# Training:  10%|█         | 15/143 [00:24<03:23,  1.59s/it, loss=0.39]
# Training:  10%|█         | 15/143 [00:25<03:23,  1.59s/it, loss=0.388]
# Training:  11%|█         | 16/143 [00:25<03:21,  1.59s/it, loss=0.388]
# Training:  11%|█         | 16/143 [00:27<03:21,  1.59s/it, loss=0.379]
# Training:  12%|█▏        | 17/143 [00:27<03:20,  1.59s/it, loss=0.379]
# Training:  12%|█▏        | 17/143 [00:28<03:20,  1.59s/it, loss=0.377]
# Training:  13%|█▎        | 18/143 [00:28<03:18,  1.59s/it, loss=0.377]
# Training:  13%|█▎        | 18/143 [00:30<03:18,  1.59s/it, loss=0.372]
# Training:  13%|█▎        | 19/143 [00:30<03:16,  1.59s/it, loss=0.372]
# Training:  13%|█▎        | 19/143 [00:32<03:16,  1.59s/it, loss=0.367]
# Training:  14%|█▍        | 20/143 [00:32<03:15,  1.59s/it, loss=0.367]
# Training:  14%|█▍        | 20/143 [00:33<03:15,  1.59s/it, loss=0.368]
# Training:  15%|█▍        | 21/143 [00:33<03:13,  1.58s/it, loss=0.368]
# Training:  15%|█▍        | 21/143 [00:35<03:13,  1.58s/it, loss=0.369]
[00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:542: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-71-07bd47b077be> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', "from sklearn.model_selection import GridSearchCV\n\nparams = {'epochs':[3, 4], 'learning_rate':[2e-5, 3e-5], 'eval_batch_size':[8, 16], 'train_batch_size':[32, 64], 'validation_fraction':[0.2, 0.3]}\n\n# wrap classifier/regressor in GridSearchCV\nclf = GridSearchCV(BertClassifier(), \n                    params,\n                    scoring='accuracy',\n                    verbose=True)\n\n# fit gridsearch \nclf.fit(X_train ,y_train)")
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/bert_sklearn/sklearn.py in fit(self, X, y, load_at_start)
#     351
#     352         # finetune model
# --> 353         self.model = fit(self.model, texts_a, texts_b, labels, config)
#     354
#     355         return self
#
# /usr/local/lib/python3.6/dist-packages/bert_sklearn/finetune.py in fit(model, X1, X2, y, config)
#     333         for step, batch in enumerate(batch_iter):
#     334             batch = tuple(t.to(device) for t in batch)
# --> 335             loss, _ = model(*batch)
#     336
#     337             loss = loss.mean()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/bert_sklearn/model.py in forward(self, input_ids, segment_ids, input_mask, labels)
#      99                                               segment_ids,
#     100                                               input_mask,
# --> 101                                               output_all_encoded_layers=False)
#     102
#     103         output = self.dropout(pooled_output)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert/modeling.py in forward(self, input_ids, token_type_ids, attention_mask, output_all_encoded_layers)
#     712         encoded_layers = self.encoder(embedding_output,
#     713                                       extended_attention_mask,
# --> 714                                       output_all_encoded_layers=output_all_encoded_layers)
#     715         sequence_output = encoded_layers[-1]
#     716         pooled_output = self.pooler(sequence_output)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states, attention_mask, output_all_encoded_layers)
#     394         all_encoder_layers = []
#     395         for layer_module in self.layer:
# --> 396             hidden_states = layer_module(hidden_states, attention_mask)
#     397             if output_all_encoded_layers:
#     398                 all_encoder_layers.append(hidden_states)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states, attention_mask)
#     380     def forward(self, hidden_states, attention_mask):
#     381         attention_output = self.attention(hidden_states, attention_mask)
# --> 382         intermediate_output = self.intermediate(attention_output)
#     383         layer_output = self.output(intermediate_output, attention_output)
#     384         return layer_output
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states)
#     353     def forward(self, hidden_states):
#     354         hidden_states = self.dense(hidden_states)
# --> 355         hidden_states = self.intermediate_act_fn(hidden_states)
#     356         return hidden_states
#     357
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert/modeling.py in gelu(x)
#     117         Also see https://arxiv.org/abs/1606.08415
#     118     """
# --> 119     return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))
#     120
#     121
#
# RuntimeError: CUDA out of memory. Tried to allocate 96.00 MiB (GPU 0; 11.17 GiB total capacity; 10.70 GiB already allocated; 80.31 MiB free; 74.09 MiB cached)

# %%
# best scores
print(clf.best_score_, clf.best_params_)

means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))

# %%
# best scores
print(clf.best_score_, clf.best_params_)

means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
